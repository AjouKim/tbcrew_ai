# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import rc

# 한글 폰트 설정 (예: Malgun Gothic)
plt.rc('font', family='Malgun Gothic')

# 유니코드에서 마이너스 기호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
csv = pd.read_csv(r"C:\Users\juh08\Downloads\20250110164508\SURFACE_ASOS_156_MI_2024-11_2024-11_2024\SURFACE_ASOS_156_MI_2024-11_2024-11_2024.csv", encoding='cp949')

# %%
csv
# Out:
#         지점                일시  기온(°C)  누적강수량(mm)  풍향(deg)  풍속(m/s)  현지기압(hPa)  \
# 0      156  2024-11-01 00:01    15.7        0.0    277.1      0.1     1014.1
# 1      156  2024-11-01 00:02    15.7        0.0    265.6      0.0     1014.1
# 2      156  2024-11-01 00:03    15.8        0.0    291.9      0.0     1014.1
# 3      156  2024-11-01 00:04    15.8        0.0    241.5      0.0     1014.0
# 4      156  2024-11-01 00:05    15.9        0.0    310.3      0.0     1014.0
# ...    ...               ...     ...        ...      ...      ...        ...
# 43194  156  2024-11-30 23:56     6.0        0.1      1.1      0.2     1009.4
# 43195  156  2024-11-30 23:57     6.0        0.1      5.9      0.3     1009.4
# 43196  156  2024-11-30 23:58     5.9        0.1      9.9      0.4     1009.4
# 43197  156  2024-11-30 23:59     5.9        0.1      7.9      0.2     1009.4
# 43198  156  2024-12-01 00:00     5.9        0.1     12.8      0.2     1009.4
#
#        해면기압(hPa)  습도(%)  일사(MJ/m^2)  일조(Sec)
# ...

# %%
csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43199 entries, 0 to 43198
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   지점          43199 non-null  int64
#  1   일시          43199 non-null  object
#  2   기온(°C)      43199 non-null  float64
#  3   누적강수량(mm)   43199 non-null  float64
#  4   풍향(deg)     43199 non-null  float64
#  5   풍속(m/s)     43199 non-null  float64
#  6   현지기압(hPa)   43199 non-null  float64
#  7   해면기압(hPa)   43199 non-null  float64
#  8   습도(%)       43199 non-null  float64
#  9   일사(MJ/m^2)  43199 non-null  float64
#  10  일조(Sec)     43199 non-null  int64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 3.6+ MB

# %%
csv.describe()
# Out:
#             지점        기온(°C)     누적강수량(mm)       풍향(deg)       풍속(m/s)  \
# count  43199.0  43199.000000  43199.000000  43199.000000  43199.000000
# mean     156.0     11.477719      1.389375    167.434702      1.269666
# std        0.0      4.830587      3.595569    116.767801      1.163376
# min      156.0      1.600000      0.000000      0.000000      0.000000
# 25%      156.0      7.500000      0.000000     45.100000      0.400000
# 50%      156.0     11.800000      0.000000    182.400000      0.900000
# 75%      156.0     14.700000      0.000000    256.300000      1.800000
# max      156.0     23.400000     18.300000    359.900000     11.200000
#
#           현지기압(hPa)     해면기압(hPa)         습도(%)    일사(MJ/m^2)       일조(Sec)
# count  43199.000000  43199.000000  43199.000000  43199.000000  43199.000000
# mean    1013.629760   1022.144895     68.375509      5.459859   9588.874742
# std        5.000671      5.069878     16.962546      5.350583  11457.325927
# ...

# %%
csv[csv['누적강수량(mm)']>0]['누적강수량(mm)'].plot.box(title='누적강수량')
# Out:
# <Axes: title={'center': '누적강수량'}>
